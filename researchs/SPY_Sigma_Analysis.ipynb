# %%
olib = OptionLib('SPY')
# Out:
# Data Updated & Built for SPY :: [ COMPLETE ]
# Latest quote: 2017-12-29 21:00:01

# %%
quandl.ApiConfig.api_key='6a7S2gxU9mg-QxfUfK_x'

# %%
olib.explore_expiry()
# Out:
#    Expiry Dates
# 0    2018-01-03
# 1    2018-01-05
# 2    2018-01-10
# 3    2018-01-12
# 4    2018-01-17
# 5    2018-01-19
# 6    2018-01-24
# 7    2018-01-26
# 8    2018-01-31
# 9    2018-02-02
# 10   2018-02-09
# 11   2018-02-16
# 12   2018-03-16
# 13   2018-03-29
# 14   2018-04-20
# 15   2018-06-15
# 16   2018-06-29
# 17   2018-07-20
# 18   2018-09-21
# 19   2018-09-28
# 20   2018-12-21
# 21   2019-01-18
# 22   2019-03-15
# 23   2019-06-21
# 24   2019-09-20
# 25   2019-12-20
# 26   2020-01-17
# 27   2020-07-17
# 28   2020-12-18

# %%
olib.opt.get_call_data()
# Out:
#                                             Last    Bid    Ask       Chg  \
# Strike Expiry     Type Symbol
# 230.0  2017-12-27 call SPY171227C00230000  37.09  37.05  37.30  0.000000
# 235.0  2017-12-27 call SPY171227C00235000  32.09  32.05  32.30  0.000000
# 240.0  2017-12-27 call SPY171227C00240000  27.15  27.04  27.30  0.000000
# 245.0  2017-12-27 call SPY171227C00245000  22.12  22.05  22.31  0.000000
# 250.0  2017-12-27 call SPY171227C00250000  17.45  17.06  17.31 -0.949999
# 255.0  2017-12-27 call SPY171227C00255000  12.21  12.05  12.32  0.000000
# 256.0  2017-12-27 call SPY171227C00256000  12.44  11.07  11.32  0.000000
# 257.0  2017-12-27 call SPY171227C00257000  10.52  10.07  10.34  0.000000
# 259.0  2017-12-27 call SPY171227C00259000   8.19   8.08   8.33  0.000000
# 260.0  2017-12-27 call SPY171227C00260000   7.41   7.08   7.35 -0.300000
# 260.5  2017-12-27 call SPY171227C00260500   6.83   6.59   6.85  3.120000
# ...

# %%
olib.plot_IV_d('c',0)
olib.plot_IV_d('p',0)
olib.plot_smile(0)

# %% [markdown]
# **Need to recheck the cause of such discrepancy...**

# %% [markdown]
# This graph clearly show the Volatity smile at time *t* for being skewed toward the OTM Put options

# %%
olib.plot_surface('c')

# %%
olib.plot_surface('p')
