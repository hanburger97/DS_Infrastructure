# %%
olib = OptionLib('UCO')
# Out:
# Data Updated & Built for UCO :: [ COMPLETE ]
# Latest quote: 2017-12-29 21:00:00

# %%
olib.data
# Out:
# Underlying @ 23.44
#  Last Option Quote: 2017-12-29 21:00:00
#                                             Last    Bid    Ask    Vol      %  \
# Strike Expiry     Type Symbol
# 1.0    2018-01-19 call UCO180119C00001000  10.80   8.90  13.00    2.0   -0.0
#                   put  UCO180119P00001000   0.01   0.00   0.55    1.0   -0.0
# 2.0    2018-01-19 call UCO180119C00002000   9.06   6.80   9.50   31.0   27.0
#                   put  UCO180119P00002000   0.45   0.00   0.45    0.0   -0.0
# 3.0    2018-01-19 call UCO180119C00003000   8.72   8.20  10.80    2.0   -3.0
#                   put  UCO180119P00003000   0.12   0.00   0.25    1.0   -0.0
#        2019-01-18 put  UCO190118P00003000   0.55   0.05   4.60    5.0   -0.0
# 4.0    2018-01-19 call UCO180119C00004000   8.40   7.60   8.30   10.0   -0.0
#                   put  UCO180119P00004000   0.25   0.15   0.35   25.0   -0.0
#        2019-01-18 call UCO190118C00004000   7.62   7.10   8.40   10.0   35.0
# ...

# %%
olib.plot_surface('p')

# %%
olib.plot_surface('c')

# %%
olib.plot_IV_d('p',0)
